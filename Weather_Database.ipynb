# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
import gmaps
from datetime import datetime

# %%
#3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
#4. Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# 5. Perform an API call with the OpenWeatherMap.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d62dd1400e54307b888d95e2483d4a2

# %%
# 6. Retrieve information from the API call:
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bukama
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 1 | mixtepec
# City not found. Skipping...
# Processing Record 11 of Set 1 | bengkulu
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | kaabong
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | katsuura
# Processing Record 16 of Set 1 | aguimes
# Processing Record 17 of Set 1 | murdochville
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | chumikan
# Processing Record 20 of Set 1 | nongan
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | salalah
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | ucluelet
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | mosquera
# Processing Record 30 of Set 1 | sao joao da barra
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | teya
# Processing Record 35 of Set 1 | chapleau
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | meulaboh
# Processing Record 38 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 1 | labuhan
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | cubuk
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | tingo maria
# Processing Record 45 of Set 1 | kautokeino
# Processing Record 46 of Set 1 | college
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | sao filipe
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | biak
# Processing Record 1 of Set 2 | owatonna
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | tarrafal
# Processing Record 5 of Set 2 | karasuk
# Processing Record 6 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 2 | andenes
# Processing Record 8 of Set 2 | reichenbach
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | japura
# Processing Record 14 of Set 2 | bathsheba
# Processing Record 15 of Set 2 | fereydun kenar
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | dunedin
# Processing Record 19 of Set 2 | panzhihua
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | naantali
# Processing Record 22 of Set 2 | vila franca do campo
# Processing Record 23 of Set 2 | tinskoy
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | rio tinto
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | macia
# Processing Record 28 of Set 2 | san benito abad
# Processing Record 29 of Set 2 | jeremie
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | nuevo casas grandes
# Processing Record 34 of Set 2 | korla
# Processing Record 35 of Set 2 | sistranda
# Processing Record 36 of Set 2 | banda aceh
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | marivan
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | moron
# Processing Record 41 of Set 2 | ashnak
# Processing Record 42 of Set 2 | cache creek
# Processing Record 43 of Set 2 | leningradskiy
# Processing Record 44 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 2 | aykhal
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | sibolga
# Processing Record 48 of Set 2 | sungaipenuh
# Processing Record 49 of Set 2 | cap malheureux
# Processing Record 50 of Set 2 | skofja loka
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | touros
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | raudeberg
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | erdenet
# Processing Record 7 of Set 3 | portland
# Processing Record 8 of Set 3 | baracoa
# Processing Record 9 of Set 3 | tonantins
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | chico
# Processing Record 12 of Set 3 | bluff
# Processing Record 13 of Set 3 | weihe
# Processing Record 14 of Set 3 | acapulco
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | crib point
# Processing Record 18 of Set 3 | caravelas
# Processing Record 19 of Set 3 | pochutla
# Processing Record 20 of Set 3 | palana
# Processing Record 21 of Set 3 | barcelos
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | mangrol
# Processing Record 24 of Set 3 | floro
# Processing Record 25 of Set 3 | yen bai
# Processing Record 26 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 3 | molochnoye
# Processing Record 28 of Set 3 | yangjiang
# Processing Record 29 of Set 3 | pantai remis
# Processing Record 30 of Set 3 | nioro
# Processing Record 31 of Set 3 | belyy yar
# Processing Record 32 of Set 3 | inuvik
# Processing Record 33 of Set 3 | mananara
# Processing Record 34 of Set 3 | richards bay
# Processing Record 35 of Set 3 | launceston
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | townsville
# Processing Record 38 of Set 3 | vestmannaeyjar
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | omaruru
# Processing Record 41 of Set 3 | visnes
# Processing Record 42 of Set 3 | dikson
# Processing Record 43 of Set 3 | vanimo
# Processing Record 44 of Set 3 | lazaro cardenas
# Processing Record 45 of Set 3 | aklavik
# Processing Record 46 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 3 | lata
# Processing Record 49 of Set 3 | comodoro rivadavia
# Processing Record 50 of Set 3 | ugoofaaru
# Processing Record 1 of Set 4 | norman wells
# Processing Record 2 of Set 4 | boguchany
# Processing Record 3 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 4 | airai
# Processing Record 5 of Set 4 | kalmunai
# Processing Record 6 of Set 4 | yarada
# Processing Record 7 of Set 4 | esperance
# Processing Record 8 of Set 4 | burnie
# Processing Record 9 of Set 4 | brest
# Processing Record 10 of Set 4 | la palma
# Processing Record 11 of Set 4 | batagay
# Processing Record 12 of Set 4 | tautira
# Processing Record 13 of Set 4 | kemin
# Processing Record 14 of Set 4 | merauke
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | kapit
# Processing Record 17 of Set 4 | santa maria
# Processing Record 18 of Set 4 | safranbolu
# Processing Record 19 of Set 4 | lorengau
# Processing Record 20 of Set 4 | kahului
# Processing Record 21 of Set 4 | samarai
# Processing Record 22 of Set 4 | mecca
# Processing Record 23 of Set 4 | buraydah
# Processing Record 24 of Set 4 | bambous virieux
# Processing Record 25 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 4 | sovetsk
# Processing Record 27 of Set 4 | linxia
# Processing Record 28 of Set 4 | la romana
# Processing Record 29 of Set 4 | chadiza
# Processing Record 30 of Set 4 | broken hill
# Processing Record 31 of Set 4 | kaeo
# Processing Record 32 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 33 of Set 4 | maanshan
# Processing Record 34 of Set 4 | fairbanks
# Processing Record 35 of Set 4 | upata
# Processing Record 36 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 4 | grindavik
# Processing Record 38 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 4 | huaral
# Processing Record 40 of Set 4 | missoula
# Processing Record 41 of Set 4 | rokytne
# Processing Record 42 of Set 4 | horki
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | road town
# Processing Record 45 of Set 4 | sambava
# Processing Record 46 of Set 4 | nome
# Processing Record 47 of Set 4 | wuwei
# Processing Record 48 of Set 4 | umm jarr
# City not found. Skipping...
# Processing Record 49 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 50 of Set 4 | kristiinankaupunki
# Processing Record 1 of Set 5 | ballstad
# City not found. Skipping...
# Processing Record 2 of Set 5 | chokurdakh
# Processing Record 3 of Set 5 | bendigo
# Processing Record 4 of Set 5 | dwarka
# Processing Record 5 of Set 5 | tura
# Processing Record 6 of Set 5 | wenatchee
# Processing Record 7 of Set 5 | mao
# Processing Record 8 of Set 5 | impfondo
# Processing Record 9 of Set 5 | kostyantynivka
# Processing Record 10 of Set 5 | saint george
# Processing Record 11 of Set 5 | camana
# Processing Record 12 of Set 5 | agirish
# Processing Record 13 of Set 5 | nishihara
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | constitucion
# Processing Record 16 of Set 5 | moyale
# Processing Record 17 of Set 5 | marawi
# Processing Record 18 of Set 5 | broome
# Processing Record 19 of Set 5 | vaini
# Processing Record 20 of Set 5 | bani walid
# Processing Record 21 of Set 5 | riyadh
# Processing Record 22 of Set 5 | lagoa
# Processing Record 23 of Set 5 | ponferrada
# Processing Record 24 of Set 5 | guerrero negro
# Processing Record 25 of Set 5 | jerusalem
# Processing Record 26 of Set 5 | kurumkan
# Processing Record 27 of Set 5 | labis
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | kaitangata
# Processing Record 30 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 5 | mokrousovo
# Processing Record 32 of Set 5 | chuy
# Processing Record 33 of Set 5 | dimitrovgrad
# Processing Record 34 of Set 5 | qarchi gak
# Processing Record 35 of Set 5 | cidreira
# Processing Record 36 of Set 5 | vardo
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | carikar
# City not found. Skipping...
# Processing Record 39 of Set 5 | san patricio
# Processing Record 40 of Set 5 | fare
# Processing Record 41 of Set 5 | ewa beach
# Processing Record 42 of Set 5 | saldanha
# Processing Record 43 of Set 5 | okhotsk
# Processing Record 44 of Set 5 | saint anthony
# Processing Record 45 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 5 | toora-khem
# Processing Record 47 of Set 5 | ribeira brava
# Processing Record 48 of Set 5 | bosaso
# Processing Record 49 of Set 5 | charters towers
# Processing Record 50 of Set 5 | malanje
# Processing Record 1 of Set 6 | coquimbo
# Processing Record 2 of Set 6 | rabo de peixe
# Processing Record 3 of Set 6 | perth
# Processing Record 4 of Set 6 | pokrovsk
# Processing Record 5 of Set 6 | monopoli
# Processing Record 6 of Set 6 | galesong
# Processing Record 7 of Set 6 | channel-port aux basques
# Processing Record 8 of Set 6 | naze
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | salihorsk
# Processing Record 11 of Set 6 | hamilton
# Processing Record 12 of Set 6 | pemberton
# Processing Record 13 of Set 6 | harper
# Processing Record 14 of Set 6 | turbat
# Processing Record 15 of Set 6 | chimbote
# Processing Record 16 of Set 6 | georgetown
# Processing Record 17 of Set 6 | aksarka
# Processing Record 18 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | severo-kurilsk
# Processing Record 21 of Set 6 | deputatskiy
# Processing Record 22 of Set 6 | nevel
# Processing Record 23 of Set 6 | abnub
# Processing Record 24 of Set 6 | banepa
# Processing Record 25 of Set 6 | ramasukha
# City not found. Skipping...
# Processing Record 26 of Set 6 | lompoc
# Processing Record 27 of Set 6 | bandarbeyla
# Processing Record 28 of Set 6 | fresno
# Processing Record 29 of Set 6 | stromness
# Processing Record 30 of Set 6 | porto nacional
# Processing Record 31 of Set 6 | colon
# Processing Record 32 of Set 6 | strezhevoy
# Processing Record 33 of Set 6 | pevek
# Processing Record 34 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | wanning
# Processing Record 37 of Set 6 | matagami
# Processing Record 38 of Set 6 | sabang
# Processing Record 39 of Set 6 | santa maria do suacui
# Processing Record 40 of Set 6 | buenaventura
# Processing Record 41 of Set 6 | macamic
# Processing Record 42 of Set 6 | anori
# Processing Record 43 of Set 6 | adrar
# Processing Record 44 of Set 6 | faanui
# Processing Record 45 of Set 6 | belmonte
# Processing Record 46 of Set 6 | hirara
# Processing Record 47 of Set 6 | sri aman
# Processing Record 48 of Set 6 | saint-joseph
# Processing Record 49 of Set 6 | pangnirtung
# Processing Record 50 of Set 6 | esqueda
# Processing Record 1 of Set 7 | baruun-urt
# Processing Record 2 of Set 7 | kawalu
# Processing Record 3 of Set 7 | odesskoye
# Processing Record 4 of Set 7 | sobolevo
# Processing Record 5 of Set 7 | itarema
# Processing Record 6 of Set 7 | sitka
# Processing Record 7 of Set 7 | gusinoye ozero
# Processing Record 8 of Set 7 | krasnoselkup
# Processing Record 9 of Set 7 | sisimiut
# Processing Record 10 of Set 7 | panjab
# Processing Record 11 of Set 7 | bilma
# Processing Record 12 of Set 7 | alofi
# Processing Record 13 of Set 7 | lodwar
# Processing Record 14 of Set 7 | hwange
# Processing Record 15 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 16 of Set 7 | inirida
# Processing Record 17 of Set 7 | shingu
# Processing Record 18 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 7 | belaya gora
# Processing Record 20 of Set 7 | chapais
# Processing Record 21 of Set 7 | puerto del rosario
# Processing Record 22 of Set 7 | half moon bay
# Processing Record 23 of Set 7 | narsaq
# Processing Record 24 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 7 | ribeira grande
# Processing Record 26 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 7 | opuwo
# Processing Record 28 of Set 7 | margate
# Processing Record 29 of Set 7 | klaksvik
# Processing Record 30 of Set 7 | cabo san lucas
# Processing Record 31 of Set 7 | hithadhoo
# Processing Record 32 of Set 7 | rassvet
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 7 | hobbs
# Processing Record 36 of Set 7 | jasper
# Processing Record 37 of Set 7 | vilyuysk
# Processing Record 38 of Set 7 | tanout
# Processing Record 39 of Set 7 | krasnomayskiy
# Processing Record 40 of Set 7 | arlit
# Processing Record 41 of Set 7 | anjiang
# Processing Record 42 of Set 7 | ocampo
# Processing Record 43 of Set 7 | maneadero
# Processing Record 44 of Set 7 | taunsa
# Processing Record 45 of Set 7 | havre-saint-pierre
# Processing Record 46 of Set 7 | solnechnyy
# Processing Record 47 of Set 7 | sangamner
# Processing Record 48 of Set 7 | axim
# Processing Record 49 of Set 7 | los llanos de aridane
# Processing Record 50 of Set 7 | muros
# Processing Record 1 of Set 8 | winnemucca
# Processing Record 2 of Set 8 | kieta
# Processing Record 3 of Set 8 | port moresby
# Processing Record 4 of Set 8 | saint-augustin
# Processing Record 5 of Set 8 | duz
# City not found. Skipping...
# Processing Record 6 of Set 8 | borba
# Processing Record 7 of Set 8 | warmbad
# Processing Record 8 of Set 8 | delmas
# Processing Record 9 of Set 8 | bowen
# Processing Record 10 of Set 8 | santa cruz de tenerife
# Processing Record 11 of Set 8 | kifri
# Processing Record 12 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 8 | nouadhibou
# Processing Record 14 of Set 8 | srednekolymsk
# Processing Record 15 of Set 8 | grand-santi
# Processing Record 16 of Set 8 | tilisos
# Processing Record 17 of Set 8 | miracatu
# Processing Record 18 of Set 8 | matay
# Processing Record 19 of Set 8 | bonoua
# Processing Record 20 of Set 8 | manokwari
# Processing Record 21 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 8 | dayong
# Processing Record 23 of Set 8 | talara
# Processing Record 24 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 25 of Set 8 | nuevitas
# Processing Record 26 of Set 8 | denpasar
# Processing Record 27 of Set 8 | ikryanoye
# Processing Record 28 of Set 8 | biltine
# Processing Record 29 of Set 8 | santa margherita ligure
# Processing Record 30 of Set 8 | port blair
# Processing Record 31 of Set 8 | tiksi
# Processing Record 32 of Set 8 | hirtshals
# Processing Record 33 of Set 8 | sola
# Processing Record 34 of Set 8 | boca do acre
# Processing Record 35 of Set 8 | pyaozerskiy
# Processing Record 36 of Set 8 | cabedelo
# Processing Record 37 of Set 8 | buenos aires
# Processing Record 38 of Set 8 | whakatane
# Processing Record 39 of Set 8 | kenai
# Processing Record 40 of Set 8 | talnakh
# Processing Record 41 of Set 8 | male
# Processing Record 42 of Set 8 | port hardy
# Processing Record 43 of Set 8 | flinders
# Processing Record 44 of Set 8 | kijang
# Processing Record 45 of Set 8 | shakiso
# Processing Record 46 of Set 8 | severnoye
# Processing Record 47 of Set 8 | shakawe
# Processing Record 48 of Set 8 | honiara
# Processing Record 49 of Set 8 | kruisfontein
# Processing Record 50 of Set 8 | ahipara
# Processing Record 1 of Set 9 | copiapo
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | berbera
# Processing Record 4 of Set 9 | byron bay
# Processing Record 5 of Set 9 | coihaique
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | muktagachha
# City not found. Skipping...
# Processing Record 8 of Set 9 | egvekinot
# Processing Record 9 of Set 9 | vila velha
# Processing Record 10 of Set 9 | rawson
# Processing Record 11 of Set 9 | north bend
# Processing Record 12 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 13 of Set 9 | mount gambier
# Processing Record 14 of Set 9 | yazman
# Processing Record 15 of Set 9 | ventspils
# Processing Record 16 of Set 9 | san policarpo
# Processing Record 17 of Set 9 | maniwaki
# Processing Record 18 of Set 9 | ciudad bolivar
# Processing Record 19 of Set 9 | dehloran
# Processing Record 20 of Set 9 | fortuna
# Processing Record 21 of Set 9 | maues
# Processing Record 22 of Set 9 | krasnyy kut
# Processing Record 23 of Set 9 | targu-lapus
# City not found. Skipping...
# Processing Record 24 of Set 9 | mongoumba
# Processing Record 25 of Set 9 | hovd
# Processing Record 26 of Set 9 | yaan
# Processing Record 27 of Set 9 | bubaque
# Processing Record 28 of Set 9 | lae
# Processing Record 29 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 9 | preobrazheniye
# Processing Record 31 of Set 9 | lavrentiya
# Processing Record 32 of Set 9 | hualmay
# Processing Record 33 of Set 9 | tilichiki
# Processing Record 34 of Set 9 | ambon
# Processing Record 35 of Set 9 | pisco
# Processing Record 36 of Set 9 | manggar
# Processing Record 37 of Set 9 | saint-jean-port-joli
# Processing Record 38 of Set 9 | cartagena
# Processing Record 39 of Set 9 | otukpo
# Processing Record 40 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 9 | haines junction
# Processing Record 42 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 9 | puerto asis
# Processing Record 44 of Set 9 | auki
# Processing Record 45 of Set 9 | casino
# Processing Record 46 of Set 9 | saint-pierre
# Processing Record 47 of Set 9 | tashara
# Processing Record 48 of Set 9 | batagay-alyta
# Processing Record 49 of Set 9 | bonthe
# Processing Record 50 of Set 9 | villavicencio
# Processing Record 1 of Set 10 | ostrovnoy
# Processing Record 2 of Set 10 | marshall
# Processing Record 3 of Set 10 | ballina
# Processing Record 4 of Set 10 | christchurch
# Processing Record 5 of Set 10 | san carlos de bariloche
# Processing Record 6 of Set 10 | lasa
# Processing Record 7 of Set 10 | hambantota
# Processing Record 8 of Set 10 | komsomolskiy
# Processing Record 9 of Set 10 | vostok
# Processing Record 10 of Set 10 | padang
# Processing Record 11 of Set 10 | otta
# Processing Record 12 of Set 10 | asau
# Processing Record 13 of Set 10 | iralaya
# Processing Record 14 of Set 10 | machachi
# Processing Record 15 of Set 10 | san quintin
# Processing Record 16 of Set 10 | buala
# Processing Record 17 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 10 | lisakovsk
# Processing Record 19 of Set 10 | shache
# Processing Record 20 of Set 10 | tuatapere
# Processing Record 21 of Set 10 | the valley
# Processing Record 22 of Set 10 | slave lake
# Processing Record 23 of Set 10 | umba
# Processing Record 24 of Set 10 | moldava nad bodvou
# Processing Record 25 of Set 10 | gigmoto
# Processing Record 26 of Set 10 | barguzin
# Processing Record 27 of Set 10 | camocim
# Processing Record 28 of Set 10 | sembe
# Processing Record 29 of Set 10 | kotelnikovo
# Processing Record 30 of Set 10 | san juan del sur
# Processing Record 31 of Set 10 | suntar
# Processing Record 32 of Set 10 | segou
# Processing Record 33 of Set 10 | gemena
# Processing Record 34 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 10 | saravan
# Processing Record 36 of Set 10 | le havre
# Processing Record 37 of Set 10 | mackenzie
# Processing Record 38 of Set 10 | ostersund
# Processing Record 39 of Set 10 | necochea
# Processing Record 40 of Set 10 | noumea
# Processing Record 41 of Set 10 | sorland
# Processing Record 42 of Set 10 | kafue
# Processing Record 43 of Set 10 | cockburn town
# Processing Record 44 of Set 10 | beyneu
# Processing Record 45 of Set 10 | ulaangom
# Processing Record 46 of Set 10 | poum
# Processing Record 47 of Set 10 | laela
# Processing Record 48 of Set 10 | dehra dun
# Processing Record 49 of Set 10 | shitkino
# Processing Record 50 of Set 10 | brainerd
# Processing Record 1 of Set 11 | praia
# Processing Record 2 of Set 11 | nkowakowa
# Processing Record 3 of Set 11 | gwadar
# Processing Record 4 of Set 11 | gao
# Processing Record 5 of Set 11 | bilibino
# Processing Record 6 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 7 of Set 11 | awjilah
# Processing Record 8 of Set 11 | muravlenko
# Processing Record 9 of Set 11 | sao jose da coroa grande
# Processing Record 10 of Set 11 | bara
# Processing Record 11 of Set 11 | ancud
# Processing Record 12 of Set 11 | pekalongan
# Processing Record 13 of Set 11 | keetmanshoop
# Processing Record 14 of Set 11 | tabou
# Processing Record 15 of Set 11 | sakakah
# Processing Record 16 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 11 | meadow lake
# Processing Record 18 of Set 11 | marang
# Processing Record 19 of Set 11 | putyatino
# Processing Record 20 of Set 11 | walvis bay
# Processing Record 21 of Set 11 | isangel
# Processing Record 22 of Set 11 | nadym
# Processing Record 23 of Set 11 | douentza
# Processing Record 24 of Set 11 | katangli
# Processing Record 25 of Set 11 | haileybury
# Processing Record 26 of Set 11 | alice springs
# Processing Record 27 of Set 11 | aviles
# Processing Record 28 of Set 11 | benguela
# Processing Record 29 of Set 11 | pringsewu
# Processing Record 30 of Set 11 | parkes
# Processing Record 31 of Set 11 | batesville
# Processing Record 32 of Set 11 | andros town
# Processing Record 33 of Set 11 | kuching
# Processing Record 34 of Set 11 | yar-sale
# Processing Record 35 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 11 | kulhudhuffushi
# Processing Record 37 of Set 11 | kaliyaganj
# Processing Record 38 of Set 11 | sungairaya
# Processing Record 39 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 40 of Set 11 | chotila
# Processing Record 41 of Set 11 | bismarck
# Processing Record 42 of Set 11 | bonavista
# Processing Record 43 of Set 11 | zhanaozen
# Processing Record 44 of Set 11 | katobu
# Processing Record 45 of Set 11 | okahandja
# Processing Record 46 of Set 11 | port hawkesbury
# Processing Record 47 of Set 11 | enumclaw
# Processing Record 48 of Set 11 | banjar
# Processing Record 49 of Set 11 | sulina
# Processing Record 50 of Set 11 | pilar de la horadada
# Processing Record 1 of Set 12 | tumarbong
# Processing Record 2 of Set 12 | paamiut
# Processing Record 3 of Set 12 | mango
# Processing Record 4 of Set 12 | shonguy
# Processing Record 5 of Set 12 | nhulunbuy
# Processing Record 6 of Set 12 | nantucket
# Processing Record 7 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 12 | forestville
# Processing Record 9 of Set 12 | maragogi
# Processing Record 10 of Set 12 | malyn
# Processing Record 11 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 12 | tapes
# Processing Record 13 of Set 12 | marsa matruh
# Processing Record 14 of Set 12 | villanueva
# Processing Record 15 of Set 12 | sinnamary
# Processing Record 16 of Set 12 | ariquemes
# Processing Record 17 of Set 12 | kilindoni
# Processing Record 18 of Set 12 | san cristobal
# Processing Record 19 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 12 | merced
# Processing Record 21 of Set 12 | xiaoshan
# Processing Record 22 of Set 12 | osoyoos
# Processing Record 23 of Set 12 | ljungby
# Processing Record 24 of Set 12 | boyolangu
# Processing Record 25 of Set 12 | puerto escondido
# Processing Record 26 of Set 12 | magan
# Processing Record 27 of Set 12 | jobner
# Processing Record 28 of Set 12 | ilhabela
# Processing Record 29 of Set 12 | vallenar
# Processing Record 30 of Set 12 | ouallam
# Processing Record 31 of Set 12 | te anau
# Processing Record 32 of Set 12 | piacabucu
# Processing Record 33 of Set 12 | kendal
# Processing Record 34 of Set 12 | vyartsilya
# Processing Record 35 of Set 12 | ponta delgada
# Processing Record 36 of Set 12 | north ridgeville
# Processing Record 37 of Set 12 | buchanan
# Processing Record 38 of Set 12 | misratah
# Processing Record 39 of Set 12 | maarianhamina
# Processing Record 40 of Set 12 | krasnyy chikoy
# Processing Record 41 of Set 12 | bestobe
# Processing Record 42 of Set 12 | portree
# Processing Record 43 of Set 12 | qaqortoq
# Processing Record 44 of Set 12 | mandalgovi
# Processing Record 45 of Set 12 | vao
# Processing Record 46 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 47 of Set 12 | tateyama
# Processing Record 48 of Set 12 | gusau
# Processing Record 49 of Set 12 | athabasca
# Processing Record 50 of Set 12 | haradok
# Processing Record 1 of Set 13 | manaure
# Processing Record 2 of Set 13 | dovolnoye
# Processing Record 3 of Set 13 | tynda
# Processing Record 4 of Set 13 | bainbridge
# Processing Record 5 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 7 of Set 13 | prokhorovka
# Processing Record 8 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 9 of Set 13 | lady frere
# Processing Record 10 of Set 13 | at-bashi
# Processing Record 11 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 13 | sabzevar
# Processing Record 13 of Set 13 | chabahar
# Processing Record 14 of Set 13 | nanzhang
# Processing Record 15 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | husavik
# Processing Record 17 of Set 13 | mozarlandia
# Processing Record 18 of Set 13 | torre-pacheco
# Processing Record 19 of Set 13 | nemuro
# Processing Record 20 of Set 13 | namibe
# Processing Record 21 of Set 13 | san antonio
# Processing Record 22 of Set 13 | cayenne
# Processing Record 23 of Set 13 | namatanai
# Processing Record 24 of Set 13 | bermeo
# Processing Record 25 of Set 13 | darasun
# Processing Record 26 of Set 13 | is
# City not found. Skipping...
# Processing Record 27 of Set 13 | abha
# Processing Record 28 of Set 13 | sept-iles
# Processing Record 29 of Set 13 | hukuntsi
# Processing Record 30 of Set 13 | nanortalik
# Processing Record 31 of Set 13 | hofn
# Processing Record 32 of Set 13 | san jose
# Processing Record 33 of Set 13 | ayagoz
# Processing Record 34 of Set 13 | belem
# Processing Record 35 of Set 13 | oksfjord
# Processing Record 36 of Set 13 | rio branco do sul
# Processing Record 37 of Set 13 | twin falls
# Processing Record 38 of Set 13 | pec
# Processing Record 39 of Set 13 | pauini
# Processing Record 40 of Set 13 | conroe
# Processing Record 41 of Set 13 | spokane
# Processing Record 42 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 13 | bhimunipatnam
# Processing Record 44 of Set 13 | isagarh
# Processing Record 45 of Set 13 | high level
# Processing Record 46 of Set 13 | trincomalee
# Processing Record 47 of Set 13 | olafsvik
# Processing Record 48 of Set 13 | dossor
# Processing Record 49 of Set 13 | mitu
# Processing Record 50 of Set 13 | puerto penasco
# Processing Record 1 of Set 14 | brenham
# Processing Record 2 of Set 14 | edd
# Processing Record 3 of Set 14 | codrington
# Processing Record 4 of Set 14 | hami
# Processing Record 5 of Set 14 | ilulissat
# Processing Record 6 of Set 14 | kumluca
# Processing Record 7 of Set 14 | boyuibe
# Processing Record 8 of Set 14 | gorgan
# Processing Record 9 of Set 14 | miri
# Processing Record 10 of Set 14 | arman
# Processing Record 11 of Set 14 | leshukonskoye
# Processing Record 12 of Set 14 | grootfontein
# Processing Record 13 of Set 14 | polunochnoye
# Processing Record 14 of Set 14 | mooi river
# City not found. Skipping...
# Processing Record 15 of Set 14 | zhigansk
# Processing Record 16 of Set 14 | kota belud
# Processing Record 17 of Set 14 | nyurba
# Processing Record 18 of Set 14 | savannah bight
# Processing Record 19 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 20 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 14 | kologriv
# Processing Record 22 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 14 | hearst
# Processing Record 24 of Set 14 | tazovskiy
# Processing Record 25 of Set 14 | uige
# Processing Record 26 of Set 14 | ystad
# Processing Record 27 of Set 14 | okandja
# City not found. Skipping...
# Processing Record 28 of Set 14 | iskateley
# Processing Record 29 of Set 14 | fayaoue
# Processing Record 30 of Set 14 | torbay
# Processing Record 31 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 32 of Set 14 | ayer itam
# City not found. Skipping...
# Processing Record 33 of Set 14 | guerande
# Processing Record 34 of Set 14 | diamantina
# Processing Record 35 of Set 14 | nanakuli
# Processing Record 36 of Set 14 | dhidhdhoo
# Processing Record 37 of Set 14 | conceicao da barra
# Processing Record 38 of Set 14 | simao
# Processing Record 39 of Set 14 | kikwit
# Processing Record 40 of Set 14 | laiagam
# City not found. Skipping...
# Processing Record 41 of Set 14 | litovko
# Processing Record 42 of Set 14 | baghmara
# Processing Record 43 of Set 14 | darnah
# Processing Record 44 of Set 14 | hanna
# Processing Record 45 of Set 14 | tinaquillo
# Processing Record 46 of Set 14 | dovers
# Processing Record 47 of Set 14 | santa ines
# Processing Record 48 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 14 | tucuman
# Processing Record 50 of Set 14 | beringovskiy
# Processing Record 1 of Set 15 | kholodnyy
# Processing Record 2 of Set 15 | wajima
# Processing Record 3 of Set 15 | quatre cocos
# Processing Record 4 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 15 | mazagao
# Processing Record 6 of Set 15 | avera
# Processing Record 7 of Set 15 | faro
# Processing Record 8 of Set 15 | kalispell
# Processing Record 9 of Set 15 | pacific grove
# Processing Record 10 of Set 15 | tiarei
# Processing Record 11 of Set 15 | mareeba
# Processing Record 12 of Set 15 | kualakapuas
# Processing Record 13 of Set 15 | linhai
# Processing Record 14 of Set 15 | vilcun
# Processing Record 15 of Set 15 | porto novo
# Processing Record 16 of Set 15 | henties bay
# Processing Record 17 of Set 15 | casian
# Processing Record 18 of Set 15 | anadyr
# Processing Record 19 of Set 15 | tromso
# Processing Record 20 of Set 15 | salekhard
# Processing Record 21 of Set 15 | qasigiannguit
# Processing Record 22 of Set 15 | ellenabad
# Processing Record 23 of Set 15 | klaipeda
# Processing Record 24 of Set 15 | kannangad
# Processing Record 25 of Set 15 | surskoye
# Processing Record 26 of Set 15 | assiniboia
# Processing Record 27 of Set 15 | winneba
# Processing Record 28 of Set 15 | haicheng
# Processing Record 29 of Set 15 | petukhovo
# Processing Record 30 of Set 15 | mitsamiouli
# Processing Record 31 of Set 15 | plaisance-du-touch
# Processing Record 32 of Set 15 | geraldton
# Processing Record 33 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 34 of Set 15 | rahon
# Processing Record 35 of Set 15 | thessalon
# Processing Record 36 of Set 15 | salta
# Processing Record 37 of Set 15 | porto belo
# Processing Record 38 of Set 15 | caborca
# Processing Record 39 of Set 15 | westport
# Processing Record 40 of Set 15 | bay city
# Processing Record 41 of Set 15 | gat
# Processing Record 42 of Set 15 | soe
# Processing Record 43 of Set 15 | coahuayana
# Processing Record 44 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 15 | pravia
# Processing Record 46 of Set 15 | jackson
# Processing Record 47 of Set 15 | karsava
# Processing Record 48 of Set 15 | san marcos
# Processing Record 49 of Set 15 | macheng
# Processing Record 50 of Set 15 | sioux lookout
# Processing Record 1 of Set 16 | turmalina
# Processing Record 2 of Set 16 | kalevala
# Processing Record 3 of Set 16 | gillette
# Processing Record 4 of Set 16 | victor harbor
# Processing Record 5 of Set 16 | tessalit
# Processing Record 6 of Set 16 | cherkasskoye
# Processing Record 7 of Set 16 | tigil
# Processing Record 8 of Set 16 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 16 | cam ranh
# Processing Record 10 of Set 16 | vanavara
# Processing Record 11 of Set 16 | ola
# Processing Record 12 of Set 16 | omboue
# Processing Record 13 of Set 16 | guarabira
# Processing Record 14 of Set 16 | eganville
# Processing Record 15 of Set 16 | tual
# Processing Record 16 of Set 16 | oudtshoorn
# Processing Record 17 of Set 16 | ambovombe
# Processing Record 18 of Set 16 | rio grande
# Processing Record 19 of Set 16 | nizhniy kuranakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bukama      CD  -9.2000   25.8500     69.19        97          99
# 1       Hobart      AU -42.8794  147.3294     85.26        54          20
# 2  Port Alfred      ZA -33.5906   26.8910     76.19        79         100
# 3      Ushuaia      AR -54.8000  -68.3000     42.46        75          40
# 4       Avarua      CK -21.2078 -159.7750     75.25        94          20
# 5     Bengkulu      ID  -3.8004  102.2655     85.39        64          90
# 6         Lebu      CL -37.6167  -73.6500     55.40        77           0
# 7      Kaabong      UG   3.4836   34.1492     72.84        43          97
# 8      Mataura      NZ -46.1927  168.8643     72.48        60          94
# 9     Katsuura      JP  35.1333  140.3000     50.14        32          91
#
#    Wind Speed Current Description
# 0        0.74          light rain
# 1        1.99          few clouds
# 2       12.44     overcast clouds
# 3       10.36    scattered clouds
# 4        4.61          light rain
# 5        6.91     overcast clouds
# 6       20.07           clear sky
# 7       12.37     overcast clouds
# 8        3.98     overcast clouds
# 9        8.41     overcast clouds

# %%
# 8. Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
